# %%
import numpy as np

# %%
a=np.random.exponential(scale=1.0,size=(4,4))

# %%
a
# Out:
# array([[1.28262498, 0.24353568, 0.43619972, 0.52149273],
#        [1.51806691, 0.60039536, 0.05254943, 0.08978178],
#        [3.32070446, 0.58935708, 0.96563291, 1.55152131],
#        [1.52069365, 0.03818874, 0.62858582, 0.98562322]])

# %%
b=np.random.exponential(scale=1.0,size=(100000,1))

# %%
b
# Out:
# array([[1.7852334 ],
#        [0.95052337],
#        [2.11664851],
#        ...,
#        [0.56736495],
#        [0.17025059],
#        [0.57999368]])

# %%
uni=np.random.rand(100000,1)

# %%
uni
# Out:
# array([[0.71465154],
#        [0.24613183],
#        [0.08221637],
#        ...,
#        [0.94386398],
#        [0.80817508],
#        [0.52754168]])

# %%
nor=np.random.randn(100000,1)

# %%
nor
# Out:
# array([[ 0.66486952],
#        [-0.9855137 ],
#        [-0.88452254],
#        ...,
#        [ 0.41647612],
#        [ 0.77806624],
#        [ 1.94241079]])

# %%
plt.hist(b, density=True, bins=100, histtype="step", color="green", label="rand")
plt.hist(uni, density=True, bins=100, histtype="step", color="blue", label="rand")
plt.hist(nor, density=True, bins=100, histtype="step", color="red", label="randn")
plt.axis([-2.5, 2.5, 0, 1.1])
plt.legend(loc = "upper left")
plt.title("Random distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %%
import matplotlib

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2

figure = plt.figure(1, figsize = (12, 4))
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0.1)
plt.show()
